# %% [markdown]
# ## Задача 1
# Рассчитайте регрессионную модель в виде Машины Вспомогательных Векторов (SVM) для датасета [../Datasets/pollution.csv](../Datasets/pollution.csv), используя только числовые колонки и строки без значений "NaN". В качестве выхода модели возьмите значение "pm2.5", а в качестве входов модели, возьмите только те, чья корреляция с колонкой "pm2.5" больше всего (имеет больше значение по сравнению с остальными).
#
# Алгоритм выполнения:
# 1. Загрузите массив данных;
# 2. Удалите из него строки и столбцы, которые вы не будете использовать;
# 3. Постройте таблицу кросс-корреляции, используя функцию corr() и отобразите ее;
# 4. Используя эту таблицу, выберите только те колонки, которые имеют существенное значение корреляции с выходной;
# 5. Выделите входные колоки в один массив (X), а выходную - в другой (Y);
# 6. Изменит размерность данных так, чтобы они имели размерность ("кол-во строк", "кол-во столбцов"), даже если столбцов - один (используйте numpy.reshape);
# 7. Разделите данные на тренировочную и тестовую выборку;
# 8. Создайте регрессор на тренировочной выборке;
# 9. Рассчитайте значение "pm2.5" по полученной модели для терновочной и тестовой выборки;
# 10. Отобразите на графике полученные тренды, сравнив их со значением из данных;
# 11. Оформите графики красиво.
#
# Ссылки:
# * [Модели в виде Машин Вспомогательных Векторов](https://scikit-learn.org/stable/modules/svm.html)
# * [Таблица кросс-корреляции в Pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)
# * [Изменение размерности массива с numpy.reshape](https://docs.scipy.org/doc/numpy/reference/generated/numpy.reshape.html)

# %%
# ваше решение
